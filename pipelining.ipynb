# %%
import amigo

# %%
data_dir = "/Users/mcha5804/JWST/IO/uncal/"
amigo.pipelines.process_calslope(data_dir)
# Out:
# Cleaning existing directory
# Running calslope processing...
#   0%|          | 0/9 [00:00<?, ?it/s]
# Done
# '/Users/mcha5804/JWST/IO/calslope/'
