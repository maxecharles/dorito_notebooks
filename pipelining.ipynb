# %%
import os
import amigo
from astropy.io import fits
# Out:
# /home/max/code/amigo/src/amigo/optical_models.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg

# %%
obj = "NGC1068"

data_dir = f"/media/morgana1/snert/max/data/JWST/{obj}/new_uncal/"
out_dir = f"/media/morgana1/snert/max/data/JWST/{obj}/calslope/"

amigo.pipelines.process_calslope(data_dir, out_dir)
# Out:
# Cleaning existing directory
# Running calslope processing...
#   0%|          | 0/76 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 data_dir = f"/media/morgana1/snert/max/data/JWST/{obj}/new_uncal/"
#       4 out_dir = f"/media/morgana1/snert/max/data/JWST/{obj}/calslope/"
# ----> 6 amigo.pipelines.process_calslope(data_dir, out_dir)
#
# File ~/code/amigo/src/amigo/pipelines.py:121, in process_calslope(input_dir, output_dir, sigma, correct_ADC, flat, clean_dir)
#     106     file[0].header["FILENAME"] = file_name
#     108     # # Remove the redundant or undesired extensions
#     109     # del file["SCI"]
#     110     # del file["GROUP"]
#    (...)    119
#     120     # Save as calslope
# --> 121     file.writeto(file_calslope, overwrite=True)
#     122     file.close()
#     124 print("Done\n")
#
# ...

# %%
# for filename in os.listdir(data_dir):
#     filepath = os.path.join(data_dir, filename)
#     # print(filename)

#     with fits.open(filepath) as hdul:
#         if hdul[0].header["EXP_TYPE"] != "NIS_AMI":
#             print(hdul[0].header["EXP_TYPE"])
#             os.remove(filepath)
#             # amigo.pipelines.process_calslope(filepath)

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2023-06-26T18:16:49.760' / UTC date file created
# ORIGIN  = 'STSCI   '           / Organization responsible for creating file
# TIMESYS = 'UTC     '           / principal time system for time-related keywords
# TIMEUNIT= 's       '           / Default unit applicable to all time values
# FILENAME= 'jw01093023001_02101_00002_nis_uncal.fits' / Name of the file
# SDP_VER = '2023_1a '           / Data processing software version number
# PRD_VER = 'PRDOPSSOC-061'      / S&OC PRD version number used in data processing
# OSS_VER = '008.004.007.000'    / Observatory Scheduling Software (OSS) version n
# DATAMODL= 'Level1bModel'       / Type of data model
# TELESCOP= 'JWST    '           / Telescope used to acquire the data
# ...

# %%
import jax.numpy as jnp

hash(jnp.float32)
# Out:
# 276896338
