# %%
from jax import numpy as np, tree
import dorito
import os
# Out:
# /Users/mc/miniconda3/envs/ami/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
source = "NGC1068"

output_dir = f"/Users/mc/data/nt_outputs/{source}/"
items = sorted(
    os.listdir(output_dir), key=lambda x: -os.path.getmtime(os.path.join(output_dir, x))
)

print(items)

output_dir = os.path.join(output_dir, items[1])
# Out:
# ['20-08-25_11-14-32.509560', '19-08-25_17-11-00.642158', '19-08-25_13-00-25.850895', '.DS_Store', '13-08-25_16-41-45.970391', '13-08-25_16-41-30.124151', '13-08-25_16-13-30.823033', '13-08-25_13-31', '13-08-25_12-37', '13-08-25_12-35', '13-08-25_11-31', '13-08-25_11-27', '12-08-25_17-36', '12-08-25_17-33', '12-08-25_16-42', '08-08-25_16-54', '08-08-25_16-49', '08-08-25_16-33', '08-08-25_15-41', '08-08-25_15-40', '08-08-25_14-49', '08-08-25_14-40', '08-08-25_14-39', '08-08-25_14-33', '08-08-25_14-23', '08-08-25_11-58', '08-08-25_11-56', '08-08-25_11-47', '08-08-25_11-35', '06-08-25_16-53', '06-08-25_16-50', '06-08-25_16-49', '06-08-25_16-27', '04-08-25_11-33', '04-08-25_10-53', '01-08-25_17-52', '01-08-25_16-20', '01-08-25_09-24', 'goodrun_params.npy', 'letstrythis.zdx', '24-07-25_03-33', '23-07-25_17-24', '22-07-25_18-50', '21-07-25_22-12', 'visibilities_O444.npy', 'O444_350.zdx', 'cal_vis_444.npy', 'visibilities_444.npy', '444_350.zdx', 'slope_counts', 'dilated_counts', '._.DS_Store
# ...

# %%
params = np.load(os.path.join(output_dir, "params.npy"), allow_pickle=True).item()
f = lambda x: (10**x) / (10**x).max()
log_dists = tree.map(f, params["log_dist"])

# %%
log_dists.keys()
# Out:
# dict_keys(['F380M', 'F430M', 'F480M'])
